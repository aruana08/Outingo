# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('True.csv')

# %%
fake = pd.read_csv('Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label'] = 1 # create new column called label with all values in that col declared as 1

# %%
fake['label'] = 0 # same thing

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news = pd.concat([fake, true], axis=0) # combining two dataframes into one larger df called news

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum() # find the sum of all null values in each category
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title','subject','date'], axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news = news.sample(frac=1) # shuffle data

# %%
news.head()
# Out:
#                                                     text  label
# 9392   Since the Colin Kaepernick and his fellow play...      0
# 3707   If there s one thing about Donald Trump that i...      0
# 19146  ISTANBUL (Reuters) - President Tayyip Erdogan ...      1
# 16519  Is there a law against waterboarding Republica...      0
# 10177  Lynnette Hardway and Rochelle Richardson of No...      0

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0   9392  Since the Colin Kaepernick and his fellow play...      0
# 1   3707  If there s one thing about Donald Trump that i...      0
# 2  19146  ISTANBUL (Reuters) - President Tayyip Erdogan ...      1
# 3  16519  Is there a law against waterboarding Republica...      0
# 4  10177  Lynnette Hardway and Rochelle Richardson of No...      0

# %%
news.drop(['index'], axis =1, inplace = True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Since the Colin Kaepernick and his fellow play...      0
# 1  If there s one thing about Donald Trump that i...      0
# 2  ISTANBUL (Reuters) - President Tayyip Erdogan ...      1
# 3  Is there a law against waterboarding Republica...      0
# 4  Lynnette Hardway and Rochelle Richardson of No...      0

# %% [markdown]
# **Data Collection and Preprocessing, Data Cleaning both done** Now, we will make the text readable

# %%
import re

# %%
def wordopt(text):
  # convert to lowercase
  text = text.lower()

  # remove urls
  text = re.sub(r'https?://\S+|www\.\S+', '', text)

  # remove html tags
  text = re.sub(r'<.*?>', '', text)

  # remove punctuation
  text = re.sub(r'[^\w\s]', '', text)

  # remove digits
  text = re.sub(r'\d', '', text)

  # remove newline chars
  text = re.sub(r'\n', ' ', text)

  return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        since the colin kaepernick and his fellow play...
# 1        if there s one thing about donald trump that i...
# 2        istanbul reuters  president tayyip erdogan wil...
# 3        is there a law against waterboarding republica...
# 4        lynnette hardway and rochelle richardson of no...
#                                ...
# 44893    comedian bill maher is no fan of republican pr...
# 44894    washington reuters  massive changes to the con...
# 44895    tune in to the alternate current radio network...
# 44896    reuters  the top democrat on the us senate ban...
# 44897    the latest video of maxine waters is downright...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        since the colin kaepernick and his fellow play...
# 1        if there s one thing about donald trump that i...
# 2        istanbul reuters  president tayyip erdogan wil...
# 3        is there a law against waterboarding republica...
# 4        lynnette hardway and rochelle richardson of no...
#                                ...
# 44893    comedian bill maher is no fan of republican pr...
# 44894    washington reuters  massive changes to the con...
# 44895    tune in to the alternate current radio network...
# 44896    reuters  the top democrat on the us senate ban...
# 44897    the latest video of maxine waters is downright...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 44893    0
# 44894    1
# 44895    0
# 44896    1
# 44897    0
# Name: label, Length: 44898, dtype: int64

# %% [markdown]
# **Dividing train data & test data**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %% [markdown]
# **Converting data (data extraction) into vectors/numerical values**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6442430 stored elements and shape (31428, 175106)>

# %%
xv_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2738407 stored elements and shape (13470, 175106)>

# %% [markdown]
# **Create ML model with logistic regression**

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train, y_train) # train model with my data
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9866369710467706

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      7015
#            1       0.98      0.99      0.99      6455
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %% [markdown]
# Use some other ML models

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.99547141796585

# %%
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7015
#            1       0.99      1.00      1.00      6455
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc=rfc.predict(xv_test)

# %%
rfc.score(xv_test, y_test)
# Out:
# 0.9870081662954714

# %%
print(classification_report(y_test, predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7015
#            1       0.98      0.99      0.99      6455
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc = gbc.predict(xv_test)

# %%
gbc.score(xv_test, y_test)
# Out:
# 0.9952487008166295

# %%
print(classification_report(y_test, pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7015
#            1       0.99      1.00      1.00      6455
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %% [markdown]
# Now that we have trained various ML models, lets create a function that will now actually predict whether a news article is fake

# %%
def output_label(n):
  if n==0:
    return "It is a Fake News"
  elif n==1:
    return "It is a Genuine News"

# %%
def manual_testing(news):
    testing_news = {"text": [news]}  # Corrected syntax for defining dictionary
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)  # Assuming 'vectorization' is your vectorizer object
    pred_lr = LR.predict(new_xv_test)
    # pred_dtc = dtc.predict(new_xv_test)
    pred_gbc = gbc.predict(new_xv_test)
    pred_rfc = rfc.predict(new_xv_test)
    return "\nLR Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(
        output_label(pred_lr[0]),
        output_label(pred_gbc[0]),
        output_label(pred_rfc[0])
    )

# %%
news_article = str(input())
# Out:
# https://timesofindia.indiatimes.com/city/bhubaneswar/odisha-man-killed-by-friend-for-spreading-fake-news-of-death/articleshow/107788768.cms

# %%
manual_testing(news_article)
# Out:
# '\nLR Prediction: It is a Fake News \nGBC Prediction: It is a Fake News \nRFC Prediction: It is a Fake News'

# %% [markdown]
# **Great! All 3 models predict that the news is fake**
